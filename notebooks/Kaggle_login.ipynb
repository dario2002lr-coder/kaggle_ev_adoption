# %%
from pathlib import Path

# Detect environment and set data directory
if Path("/kaggle/input").exists():
    # Kaggle environment
    DATA_DIR = Path("/kaggle/input/competitions/playground-series-s6e9")
else:
    # Local environment
    PROJECT_ROOT = Path.cwd().parent
    DATA_DIR = PROJECT_ROOT / "data" / "raw"


print(f"Data directory: {DATA_DIR}")
# Out:
# Data directory: c:\Users\Darío\Desktop\KAGGLE\Predicting_Electric_Vehicle_Purchases\data\raw

# %%
import kagglehub

kagglehub.login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://www.kaggle.com/static/images/site-logo.png\nalt=\'Kaggle…

# %%
print(kagglehub.whoami())
# Out:
# Kaggle credentials successfully validated.
# {'username': 'dariolr'}

# %%
path = kagglehub.competition_download(
    "playground-series-s6e9",
    output_dir=DATA_DIR
)

print(path)
# Out:
# Downloading to c:\Users\Darío\Desktop\KAGGLE\Predicting_Electric_Vehicle_Purchases\data\raw\playground-series-s6e9.archive...
# 100%|██████████| 14.1M/14.1M [00:00<00:00, 15.4MB/s]
# Extracting files...
# c:\Users\Darío\Desktop\KAGGLE\Predicting_Electric_Vehicle_Purchases\data\raw
